# %%
Def sticks : {ap {| ^}:B}

# %%
import : dir co : up : .

# %%
count : theorem (simple:sticks) : S1? 
count : theorem (idempotent:sticks) : S1?
count : theorem (distributive:sticks): S1?
# Out:
# 0
# 4
# 0

# %%
Def ring : ar {| ^}

# %%
count : theorem (simple:ring) : S1?
count : theorem (idempotent:ring) : S1?
count : theorem (distributive:ring) : S1?
# Out:
# 16
# 0
# 0

# %%
count : theorem (space_a:ring) : S1?
# Out:
# 96

# %%
count : theorem (space_b:ring) : S1?
# Out:
# 92

# %%
count : theorem (ring_left:ring) : S1?
count : theorem (ring_right:ring) : S1?
# Out:
# 0
# 0

# %%
ring a b : a ga ga g
# Out:
# | ^ | ^ | ^ | ^ | ^ | ^ | ^ | ^

# %%
ar {| ^} a b : c d e
# Out:
# | ^ | ^ | ^ | ^ | ^ | ^

# %%
Def ring2 : {rev:first 2:B}

# %%
Def test : {ar {rev:first 2:B} : B}

# %%
Def T : ar {rev:first A:B}

# %%
count : theorem (ring_left:T) : S1?
# Out:
# (count:(if (not:(equal (rev:(first ◎:◎)):(rev:(first ◎:◎)))):(with (def y:{A}) (def z:{A} ◎) (def x:{A} ◎):(equal (rev:(first ◎:◎)):(rev:(first ◎:◎))))) (if (not:(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)))):(with (def y:{A}) (def z:{A} ◎) (def x:{A} ◎ ◎):(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎))))) (if (not:(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)))):(with (def y:{A}) (def z:{A} ◎) (def x:{A} ◎ ◎ ◎):(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎))))) (if (not:(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)))):(with (def y:{A}) (def z:{A} ◎) (def x:{A} ◎ ◎ ◎ ◎):(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)) (r
# ...

# %%
count : theorem (ring_right:T) : S1?
# Out:
# (count:(if (not:(equal (rev:(first ◎:◎)):(rev:(first ◎:◎)))):(with (def y:{A}) (def z:{A} ◎) (def x:{A} ◎):(equal (rev:(first ◎:◎)):(rev:(first ◎:◎))))) (if (not:(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)))):(with (def y:{A}) (def z:{A} ◎) (def x:{A} ◎ ◎):(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎))))) (if (not:(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)))):(with (def y:{A}) (def z:{A} ◎) (def x:{A} ◎ ◎ ◎):(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎))))) (if (not:(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)))):(with (def y:{A}) (def z:{A} ◎) (def x:{A} ◎ ◎ ◎ ◎):(equal (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)) (rev:(first ◎:◎)):(rev:(first ◎:◎)) (rev:(first ◎:◎)) (r
# ...
