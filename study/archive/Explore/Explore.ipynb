# %% [markdown]
# # Exploration
#
# This is going to be a general exploration of some data, particularly exercising the Set module.
#
# The Sample module also can generate all pure data up to specified with and depth, but this results in enormous data samples and it's impractical to search deep enough to hit the built in definitions.
#
# We will look for data using the samples available from the Set module:
#
# 1. nilpotents A^n:X = ()
# 2. involutions A:A:X = X
# 3. idempotents A:A:X = A:X
# 4. distributive A:X Y = (A:X) (A:Y)
# 5. space A:(A:X) (A:Y) = A:X Y
# 6. morphism from A to B F:A:X = B:F:X

# %%
from base import * 
import Sample,Set 

DOMAIN = Sample.Domain(*Sample.codas)
TINY = Set.Set(*[data(c) for c in Sample.codas])
S21 = Set.Set(*DOMAIN.window(2,1))
S31 = Set.Set(*DOMAIN.window(3,1))
S22 = Set.Set(*DOMAIN.window(2,2)) 
PURE = Sample.pure(2,2)
#S41 = Set.Set(*DOMAIN.window(4,1))
#
#     The evaluation depth is controlled by these 
#
e10   = Set.eval10
e100  = Set.eval100  
e1000 = Set.eval1000  
#
#    Samples of (:) "hydrogen atoms"
#
def atoms(n): return Sample.oddAtoms(n)+Sample.evenAtoms(n)

# %%
for s in S31.sample(10): print(s)
# Out:
# 𝝞 2 by
# int_div if rep
# not = 1
# bool A once
# int_sum pass =
# get aq if
# = {$} rep
# count and 2
# nats ap or
# (X:) ints equal

# %% [markdown]
# A zeroth order study is to find out if any of the base codas have algebraic properties.  The base codas are in TINY.

# %%
','.join([str(t) for t in TINY])
# Out:
# '◎,𝟬,𝝞,pass,null,bin,put,get,domain,left,right,if,nif,*,nat,ints,int_sum,int_prod,int_sort,int_min,int_max,int_inv,int_div,nats,rev,first,tail,last,rep,nth1,once,count,bool,not,=,equal,or,and,nor,xor,nand,xnor,iff,imply,some,ap,aq,by,ax,0,1,2,3,a,b,A,B,(X:),(Y:),(Z:),(W:),(X:),(Y:),(Z:),(W:),{$}'

# %%
SEARCH = S21
DOM1 = S22.sample(10)+atoms(5) 
DOM2 = S22.sample(10)+atoms(5)
#DOM1 = S22.sample(20)+atoms(5)+PURE.sample(10) 
#DOM2 = S22.sample(20)+atoms(5)+PURE.sample(10)
print(len(SEARCH),len(DOM1),len(DOM2))
# Out:
# 4489 20 20

# %%
def pr(x): 
    L = [str(xx) for xx in x.empty()]
    L.sort()
    print(str(len(L))+' '+','.join(L))

# %%
equivalence = S21.equivalence(atoms(2),atoms(2),atoms(2)).multieval(e100)
pr(equivalence)
# Out:
# Process SpawnPoolWorker-12:
# Process SpawnPoolWorker-9:
# Process SpawnPoolWorker-3:
# Process SpawnPoolWorker-4:
# Process SpawnPoolWorker-11:
# Process SpawnPoolWorker-2:
# Process SpawnPoolWorker-10:
# Process SpawnPoolWorker-7:
# Process SpawnPoolWorker-1:
# Process SpawnPoolWorker-8:
# Process SpawnPoolWorker-6:
# Process SpawnPoolWorker-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/youssef/coda/py/Set.py", line 10, in eval100
#     def eval100(S): return S.eval(100)
#   File "/Users/youssef/coda/py/Set.py", line 66, in eval
#     while D.undecided() and i<maxiter: D,i = D.eval(),i+1
#   File "/Users/youssef/coda/py/Set.py", line 10, in eval100
#     def eval100(S): return S.eval(100)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/Set.py", line 10, in eval100
#     def eval100(S): return S.eval(100)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/youssef/coda/py/Set.py", line 66, in eval
#     while D.undecided() and i<maxiter: D,i = D.eval(),i+1
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/youssef/coda/py/Set.py", line 66, in eval
#     while D.undecided() and i<maxiter: D,i = D.eval(),i+1
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/youssef/coda/py/base.py", line 79, in eval
#     return CONTEXT(c)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/youssef/coda/py/Set.py", line 10, in eval100
#     def eval100(S): return S.eval(100)
#   File "/Users/youssef/coda/py/Set.py", line 10, in eval100
#     def eval100(S): return S.eval(100)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
# Traceback (most recent call last):
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/Set.py", line 10, in eval100
#     def eval100(S): return S.eval(100)
#   File "/Users/youssef/coda/py/Set.py", line 66, in eval
#     while D.undecided() and i<maxiter: D,i = D.eval(),i+1
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/youssef/coda/py/Set.py", line 66, in eval
#     while D.undecided() and i<maxiter: D,i = D.eval(),i+1
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 120, in __call__
#     if c in self:
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/Set.py", line 66, in eval
#     while D.undecided() and i<maxiter: D,i = D.eval(),i+1
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/youssef/coda/py/Set.py", line 10, in eval100
#     def eval100(S): return S.eval(100)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 111, in __contains__
#     def __contains__(self,c): return self.domain(c) in self._definitions
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/youssef/coda/py/Set.py", line 66, in eval
#     while D.undecided() and i<maxiter: D,i = D.eval(),i+1
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/Set.py", line 10, in eval100
#     def eval100(S): return S.eval(100)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 108, in domain
#     d = c.domain(); s = str(d)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/youssef/coda/py/base.py", line 18, in __str__
#     def __str__(self): return UNICODE.data(self)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/Set.py", line 10, in eval100
#     def eval100(S): return S.eval(100)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/Set.py", line 66, in eval
#     while D.undecided() and i<maxiter: D,i = D.eval(),i+1
#   File "/Users/youssef/coda/py/base.py", line 189, in data
#     def data(self,D,sep=' '): return sep.join([self.coda(c) for c in D])
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 189, in <listcomp>
#     def data(self,D,sep=' '): return sep.join([self.coda(c) for c in D])
#   File "/Users/youssef/coda/py/Set.py", line 66, in eval
#     while D.undecided() and i<maxiter: D,i = D.eval(),i+1
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 79, in eval
#     return CONTEXT(c)
#   File "/Users/youssef/coda/py/base.py", line 192, in coda
#     if c.domain() in [data(ATOMS.atom),data(ATOMS.bit0),data(ATOMS.bit1)]: return self.data(c.right(),'')
#   File "/Users/youssef/coda/py/base.py", line 79, in eval
#     return CONTEXT(c)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 120, in __call__
#     if c in self:
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 122, in __call__
#     return self._cache[c]
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 189, in data
#     def data(self,D,sep=' '): return sep.join([self.coda(c) for c in D])
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 111, in __contains__
#     def __contains__(self,c): return self.domain(c) in self._definitions
#   File "/Users/youssef/coda/py/base.py", line 57, in __hash__
#     def __hash__(self): return hash((self._left,self._right,))
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 108, in domain
#     d = c.domain(); s = str(d)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 17, in __hash__
#     def __hash__(self): return hash(tuple(self._sequence))
#   File "/Users/youssef/coda/py/base.py", line 189, in <listcomp>
#     def data(self,D,sep=' '): return sep.join([self.coda(c) for c in D])
#   File "/Users/youssef/coda/py/base.py", line 57, in __hash__
#     def __hash__(self): return hash((self._left,self._right,))
# Traceback (most recent call last):
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 65, in domain
#     def domain(self): return self.left().split()[0]
#   File "/Users/youssef/coda/py/base.py", line 79, in eval
#     return CONTEXT(c)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 17, in __hash__
#     def __hash__(self): return hash(tuple(self._sequence))
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
# Traceback (most recent call last):
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 27, in split
#     def split(self): return data(*self[:1]),data(*self[1:])
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 79, in eval
#     return CONTEXT(c)
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 25, in __getitem__
#     def __getitem__(self,i): return self._sequence[i]
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/youssef/coda/py/base.py", line 120, in __call__
#     if c in self:
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
# KeyboardInterrupt
#   File "/Users/youssef/coda/py/base.py", line 122, in __call__
#     return self._cache[c]
#   File "/Users/youssef/coda/py/base.py", line 57, in __hash__
#     def __hash__(self): return hash((self._left,self._right,))
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/youssef/coda/py/base.py", line 17, in __hash__
#     def __hash__(self): return hash(tuple(self._sequence))
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 57, in __hash__
#     def __hash__(self): return hash((self._left,self._right,))
#   File "/Users/youssef/coda/py/base.py", line 111, in __contains__
#     def __contains__(self,c): return self.domain(c) in self._definitions
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 191, in coda
#     if c in self: return self[c]
#   File "/Users/youssef/coda/py/base.py", line 57, in __hash__
#     def __hash__(self): return hash((self._left,self._right,))
#   File "/Users/youssef/coda/py/base.py", line 175, in __contains__
#     def __contains__(self,c): return c in self._map
#   File "/Users/youssef/coda/py/base.py", line 59, in __eq__
#     def __eq__(self,c): return self.left()==c.left() and self.right()==c.right()
#   File "/Users/youssef/coda/py/base.py", line 19, in __eq__
#     def __eq__(self,A): return self._sequence==A._sequence
#   File "/Users/youssef/coda/py/base.py", line 59, in __eq__
#     def __eq__(self,c): return self.left()==c.left() and self.right()==c.right()
#   File "/Users/youssef/coda/py/base.py", line 19, in __eq__
#     def __eq__(self,A): return self._sequence==A._sequence
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 108, in domain
#     d = c.domain(); s = str(d)
#   File "/Users/youssef/coda/py/base.py", line 79, in eval
#     return CONTEXT(c)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 121, in __call__
#     if c in self._cache:
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/youssef/coda/py/base.py", line 18, in __str__
#     def __str__(self): return UNICODE.data(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/youssef/coda/py/base.py", line 78, in eval
#     c = self.left().eval() | self.right().eval()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 17, in __hash__
#     def __hash__(self): return hash(tuple(self._sequence))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/youssef/coda/py/base.py", line 189, in data
#     def data(self,D,sep=' '): return sep.join([self.coda(c) for c in D])
#   File "/Users/youssef/coda/py/base.py", line 59, in __eq__
#     def __eq__(self,c): return self.left()==c.left() and self.right()==c.right()
#   File "/Users/youssef/coda/py/base.py", line 79, in eval
#     return CONTEXT(c)
#   File "/Users/youssef/coda/py/base.py", line 57, in __hash__
#     def __hash__(self): return hash((self._left,self._right,))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/Users/youssef/coda/py/base.py", line 17, in __hash__
#     def __hash__(self): return hash(tuple(self._sequence))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/youssef/coda/py/base.py", line 121, in __call__
#     if c in self._cache:
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/youssef/coda/py/base.py", line 79, in eval
#     return CONTEXT(c)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/youssef/coda/py/base.py", line 49, in eval
#     for d in c.eval(): result.append(d)
#   File "/Users/youssef/coda/py/base.py", line 189, in <listcomp>
#     def data(self,D,sep=' '): return sep.join([self.coda(c) for c in D])
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/Users/youssef/coda/py/base.py", line 57, in __hash__
#     def __hash__(self): return hash((self._left,self._right,))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/Users/youssef/coda/py/base.py", line 120, in __call__
#     if c in self:
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/Users/youssef/coda/py/base.py", line 79, in eval
#     return CONTEXT(c)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/Users/youssef/coda/py/base.py", line 111, in __contains__
#     def __contains__(self,c): return self.domain(c) in self._definitions
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/youssef/coda/py/base.py", line 120, in __call__
#     if c in self:
# KeyboardInterrupt
#   File "/Users/youssef/coda/py/base.py", line 108, in domain
#     d = c.domain(); s = str(d)
#   File "/Users/youssef/coda/py/base.py", line 111, in __contains__
#     def __contains__(self,c): return self.domain(c) in self._definitions
# KeyboardInterrupt
#   File "/Users/youssef/coda/py/base.py", line 65, in domain
#     def domain(self): return self.left().split()[0]
#   File "/Users/youssef/coda/py/base.py", line 108, in domain
#     d = c.domain(); s = str(d)
#   File "/Users/youssef/coda/py/base.py", line 27, in split
#     def split(self): return data(*self[:1]),data(*self[1:])
#   File "/Users/youssef/coda/py/base.py", line 65, in domain
#     def domain(self): return self.left().split()[0]
#   File "/Users/youssef/coda/py/base.py", line 15, in __init__
#     def __init__(self,*codas): self._sequence = codas
#   File "/Users/youssef/coda/py/base.py", line 27, in split
#     def split(self): return data(*self[:1]),data(*self[1:])
#   File "/Users/youssef/coda/py/base.py", line 15, in __init__
#     def __init__(self,*codas): self._sequence = codas
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 equivalence = S21.equivalence(atoms(2),atoms(2),atoms(2)).multieval(e100)
#       2 pr(equivalence)
#
# File ~/coda/py/Set.py:56, in Subset.multieval(self, eval, nproc)
#      54 n = 0
#      55 LOG('multi','Number of processors',str(nproc))
# ---> 56 for result in pool.imap_unordered(eval,S_split):
#      57     n += 1
#      58     LOG('multi',str(n)+'...')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
E2 = equivalence.empty()
E3 = E2.equivalence(DOM1,DOM1,DOM1).multieval(e100)

# %%
E4 = E3.empty()

# %%
DOM = S22.sample(40)+atoms(5)+PURE.sample(10)
E5 = E4.equivalence(DOM,DOM,DOM).multieval(e100).empty()

# %%
for s in S21.sample(5): print(s)

# %%
idempotent = SEARCH.idempotent(DOM1).multieval(e100)
pr(idempotent)

# %%
nilpotent = SEARCH.nilpotent(1,DOM1).multieval(e100) 
pr(nilpotent)

# %%
involution = SEARCH.involution(1,DOM1).multieval(e100)
pr(involution)

# %%
space = SEARCH.space(DOM1,DOM2).multieval(e100)
pr(space)
