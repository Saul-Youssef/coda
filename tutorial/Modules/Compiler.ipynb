# %%
from base import *
import Evaluate

# %%
A = da('{first 3: a b c d e f g}:')

# %%
D = Evaluate.resolve(A,100)

# %%
D
# Out:
# (((:):(:)):(((:):):((:):)((:):(:))((:):(:))((:):(:))((:):(:))((:):)((:):(:))((:):(:)))(((:):):((:):)((:):(:))((:):(:))((:):)((:):)((:):(:))((:):(:))((:):))(((:):):((:):)((:):(:))((:):(:))((:):)((:):(:))((:):)((:):)((:):(:)))(((:):):((:):)((:):(:))((:):(:))((:):(:))((:):)((:):)((:):(:))((:):))(((:):):((:):)((:):(:))((:):(:))((:):(:))((:):)((:):)((:):(:))((:):(:)))(((:):):((:):)((:):(:))((:):(:))((:):(:))((:):)((:):(:))((:):)((:):))(((:):):((:):)((:):)((:):(:))((:):)((:):)((:):)((:):)((:):))(((:):):((:):)((:):)((:):(:))((:):(:))((:):)((:):)((:):(:))((:):(:)))(((:):):((:):)((:):)((:):(:))((:):(:))((:):(:))((:):)((:):(:))((:):))(((:):):((:):)((:):)((:):(:))((:):)((:):)((:):)((:):)((:):))(((:):):((:):)((:):(:))((:):(:))((:):)((:):)((:):)((:):)((:):(:)))(((:):):((:):)((:):)((:):(:))((:):)((:):)((:):)((:):)((:):))(((:):):((:):)((:):(:))((:):(:))((:):)((:):)((:):)((:):(:))((:):))(((:):):((:):)((:):)((:):(:))((:):)((:):)((:):)((:):)((:):))(((:):):((:):)((:):(:))((:):(:))((:):)((:):)((:):)((:)
# ...

# %%
for d in D: print(d)
# Out:
# {first 3: a b c d e f g}:

# %%
from Compile import compile
print(compile('rev : a b c'))
# Out:
# c b a
