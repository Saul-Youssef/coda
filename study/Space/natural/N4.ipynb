# %%
defaultTime:1000
# Out:
# (defaultTime:1000)

# %%
import : dir co : up : .

# %%
Def N : (front | | | |) * (ap const |)

# %%
N :

# %%
N : a b c d e 
N : N : a b c d e 
N : (N : a) (N : b c d e)
# Out:
# | | | |
# | | | |
# | | | |

# %%
Def e : end N

# %%
(e:pass) : | | | | | | | | |
# Out:
# | | | |

# %%
Let Domain : (:) (:|) (:| |) (:| | |) (:| | | |)

# %%
count : permutation 5 : Domain?
# Out:
# 3125

# %%
Def F : {(if (B):(get:nth 1:A)) (if (B=|):(get:nth 2:A)) (if (B=(| |)):(get:nth 3:A)) (if (B=(| | |)):(get:nth 4:A)) (if (B=(| | | |)):(get:nth 5:A))}

# %%
F (:a) (:b) (:c) (:d) (:e): 
F (:a) (:b) (:c) (:d) (:e): | 
F (:a) (:b) (:c) (:d) (:e): | |  
F (:a) (:b) (:c) (:d) (:e): | | | 
F (:a) (:b) (:c) (:d) (:e): | | | |
F (:a) (:b) (:c) (:d) (:e): | | | | |
# Out:
# a
# b
# c
# d
# e

# %%
Let Endomorphisms : ap {:F (get:B)} : permutation 5 : Domain?

# %%
count : Endomorphisms?
# Out:
# 3125

# %%
#dom 100 : ap {with (get:B) : bool : idempotent (e:get:B) : Domain?} : Endomorphisms?

# %%
Let Idempotents : ap {if (right:B):(:arg:B)} : dom 200 : ap {with (get:B) : bool : idempotent (e:get:B) : Domain?} : Endomorphisms?

# %%
count : Idempotents?
# Out:
# (count:(ap {if (right:B):(:arg:B)}:(with F ◎ ◎ ◎ ◎ ◎:) (with F ◎ ◎ ◎ ◎ (:|):◎) (with F ◎ ◎ ◎ ◎ (:| |):◎) (with F ◎ ◎ ◎ ◎ (:| | |):◎) (with F ◎ ◎ ◎ ◎ (:| | | |):) (with F ◎ ◎ ◎ (:|) ◎:◎) (with F ◎ ◎ ◎ (:|) (:|):◎) (with F ◎ ◎ ◎ (:|) (:| |):◎) (with F ◎ ◎ ◎ (:|) (:| | |):◎) (with F ◎ ◎ ◎ (:|) (:| | | |):◎) (with F ◎ ◎ ◎ (:| |) ◎:◎) (with F ◎ ◎ ◎ (:| |) (:|):◎) (with F ◎ ◎ ◎ (:| |) (:| |):◎) (with F ◎ ◎ ◎ (:| |) (:| | |):◎) (with F ◎ ◎ ◎ (:| |) (:| | | |):◎) (with F ◎ ◎ ◎ (:| | |) ◎:) (with F ◎ ◎ ◎ (:| | |) (:|):◎) (with F ◎ ◎ ◎ (:| | |) (:| |):◎) (with F ◎ ◎ ◎ (:| | |) (:| | |):) (with F ◎ ◎ ◎ (:| | |) (:| | | |):) (with F ◎ ◎ ◎ (:| | | |) ◎:◎) (with F ◎ ◎ ◎ (:| | | |) (:|):◎) (with F ◎ ◎ ◎ (:| | | |) (:| |):◎) (with F ◎ ◎ ◎ (:| | | |) (:| | |):◎) (with F ◎ ◎ ◎ (:| | | |) (:| | | |):) (with F ◎ ◎ (:|) ◎ ◎:◎) (with F ◎ ◎ (:|) ◎ (:|):◎) (with F ◎ ◎ (:|) ◎ (:| |):◎) (with F ◎ ◎ (:|) ◎ (:| | |):◎) (with F ◎ ◎ (:|) ◎ (:| | | |):◎) (with F ◎ ◎ (:|) (:|) ◎:◎) (with F ◎ ◎ (:|) (:|) (:|):◎) (wi
# ...

# %%
write N4.spaces 5000 : dom 5000 : ap {with (get:B) : bool : ap preSpace (e:get:B) : permutation 2 : Domain?} : Idempotents?

# %%
tab : ap {if (right:B):B} : read : N4.spaces
