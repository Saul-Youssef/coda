# %%
defaultTime:5000
# Out:
# (defaultTime:5000)

# %%
import : dir co : up : up : up : .

# %%
Def F  : ap { if (right:B):(:arg:B)}  
Def nF : ap {nif (right:B):(:arg:B)}

# %%
log:eval.step
# Out:
# eval.step> step 3, time:0.01/5000.00, GB:0.10/2.00, context:222, cache:737/11

# %%
Let Domain : first 10000 : C13?:
# Out:
# eval.step> step 16, time:1.45/5000.00, GB:0.10/2.00, context:223, cache:758/1

# %%
tab : first 150 : Domain?
# Out:
# eval.step> step 64, time:191.82/5000.00, GB:0.54/2.00, context:223, cache:1505/9846
#  (:=)
#  (:ab)
#  (:and)
#  (:ap)
#  (:apby)
#  (:aq)
#  (:ar)
#  (:arg)
#  (:as)
#  (:bin)
#  (:bool)
#  (:by)
#  (:co)
#  (:collect)
#  (:const)
#  (:count)
#  (:domain)
#  (:equal)
#  (:equiv)
#  (:first)
#  (:float_div)
#  (:float_inv)
#  (:float_max)
#  (:float_min)
#  (:float_prod)
#  (:float_sort)
#  (:float_sum)
#  (:floats)
#  (:get)
#  (:has)
#  (:hasnt)
#  (:head)
#  (:if)
#  (:iff)
#  (:imply)
#  (:int_div)
#  (:int_inv)
#  (:int_max)
#  (:int_min)
#  (:int_prod)
#  (:int_sort)
#  (:int_sum)
#  (:ints)
#  (:is)
#  (:isnt)
#  (:ker)
#  (:kernel)
#  (:last)
#  (:left)
#  (:nand)
#  (:nat)
#  (:nat_max)
#  (:nat_min)
#  (:nat_prod)
#  (:nat_sort)
#  (:nat_sum)
#  (:nats)
#  (:nif)
#  (:nor)
#  (:not)
#  (:nth)
#  (:nth1)
#  (:null)
#  (:once)
#  (:or)
#  (:pass)
#  (:plus)
#  (:post)
#  (:pre)
#  (:prod)
#  (:put)
#  (:rep)
#  (:rev)
#  (:right)
#  (:ring)
#  (:skip)
#  (:some)
#  (:star)
# ...

# %%
write L1 7200 : dom 1000 : property algebraic_L1 S7? : Domain?
# Out:
# eval.step> step 51, time:5529.89/7200.00, GB:5.65/2.00, context:223, cache:20971/19438
# eval.step> step 5, time:5622.88/5000.00, GB:2.49/2.00, context:223, cache:1521/9873

# %%
tab : first 200 :  read stable : L1
# Out:
# eval.step> step 32, time:293.61/5000.00, GB:4.61/2.00, context:223, cache:2225/10324
#  (with =:◎)
#  (with ab:◎)
#  (with and:)
#  (with ap:◎)
#  (with apby:◎)
#  (with aq:)
#  (with ar:)
#  (with arg:)
#  (with bin:◎)
#  (with bool:)
#  (with by:◎)
#  (with co:◎)
#  (with collect:◎)
#  (with const:)
#  (with count:)
#  (with domain:)
#  (with equal:◎)
#  (with equiv:◎)
#  (with first:◎)
#  (with float_div:◎)
#  (with float_inv:◎)
#  (with float_max:)
#  (with float_min:)
#  (with float_prod:)
#  (with float_sort:)
#  (with float_sum:)
#  (with floats:◎)
#  (with get:◎)
#  (with has:◎)
#  (with hasnt:◎)
#  (with head:)
#  (with if:◎)
#  (with iff:)
#  (with imply:)
#  (with int_div:◎)
#  (with int_inv:◎)
#  (with int_max:)
#  (with int_min:)
#  (with int_prod:)
#  (with int_sort:)
#  (with int_sum:)
#  (with ints:◎)
#  (with is:)
#  (with isnt:◎)
#  (with ker:)
#  (with kernel:)
#  (with last:◎)
#  (with left:)
#  (with nand:)
#  (with nat:◎)
#  (with nat_max:)
#  (with nat_min:)
# ...

# %%
write L2 7200 : dom 1000 : property algebraic_L2 S7? : F : read stable : L1
# Out:
# eval.step> step 29, time:34280.64/7200.00, GB:5.89/2.00, context:223, cache:39597/714
# eval.step> step 5, time:34323.05/5000.00, GB:5.57/2.00, context:223, cache:2237/10344

# %%
write L2R1 3600 : dom 1000 : property algebraic_R1 S7? : F : read stable : L2
# Out:
# eval.step> step 29, time:8034.10/3600.00, GB:6.13/2.00, context:223, cache:18728/686
# eval.step> step 4, time:8036.64/5000.00, GB:6.07/2.00, context:223, cache:2250/10365

# %%
write L2R1.idem 1200 : dom 1000 : property idempotent S7? : F : read stable : L2R1
# Out:
# eval.step> step 29, time:1547.67/1200.00, GB:6.05/2.00, context:223, cache:17411/605
# eval.step> step 5, time:1549.44/5000.00, GB:6.03/2.00, context:223, cache:2264/10388

# %%
write L2R1.nidem.semi 1200 : dom 1000 : property semilattice S7? : nF : read stable : L2R1.idem
# Out:
# eval.step> step 29, time:394.65/1200.00, GB:6.03/2.00, context:223, cache:18946/1022
# eval.step> step 5, time:395.01/5000.00, GB:6.03/2.00, context:223, cache:44982/89327

# %%
tab : read stable : L2R1.nidem.semi
# Out:
# eval.step> step 23, time:2.17/5000.00, GB:6.03/2.00, context:223, cache:47491/89881
#  (with count:◎)
#  (with nand:)
#  (with not:)
#  (with xor:)
#  (with xnor int_div:)
#  (with iff {B tail}:)
#  (with nor {ker B}:)
#  (with iff count:)
#  (with nor xnor:)
#  (with xnor {collect B}:)
#  (with not {B : swap}:)
#  (with xnor {float_sum : B}:)
#  (with count ints:◎)
#  (with count {nats B}:◎)
#  (with not {int_sort B}:)
#  (with nor nth:)
#  (with xnor {B : once}:)
#  (with count {B a}:◎)
#  (with count {pass B}:◎)
#  (with count swap:◎)
#  (with nor {right B}:)
#  (with count {pre B}:◎)
#  (with nor {B : 0}:)
#  (with count {B : (:-1 : 1)}:◎)
#  (with {nand : B} B:)
#  (with nor {B if}:)
#  (with iff {xnor B}:)
#  (with count {int_max B}:◎)
#  (with xnor ints:)
#  (with not sum:)
#  (with iff {B : nat_sum}:)
#  (with not {B : not}:)
#  (with nor not:)
#  (with iff {B some}:)
#  (with not {B swap}:)
#  (with nor {B nand}:)
#  (with not {or B}:)
#  (with iff {B float_sort}:)
# ...

# %%
tab : ap {nif (right:B):B} : nF : read stable : L2R1.idem
# Out:
# eval.step> step 32, time:107.72/5000.00, GB:5.95/2.00, context:223, cache:21368/16169
#  (with count:◎)
#  (with nand:◎)
#  (with not:◎)
#  (with xor:◎)
#  (with xnor int_div:◎)
#  (with iff {B tail}:◎)
#  (with nor {ker B}:◎)
#  (with iff count:◎)
#  (with nor xnor:◎)
#  (with xnor {collect B}:◎)
#  (with not {B : swap}:◎)
#  (with xnor {float_sum : B}:◎)
#  (with count ints:◎)
#  (with count {nats B}:◎)
#  (with not {int_sort B}:◎)
#  (with nor nth:◎)
#  (with xnor {B : once}:◎)
#  (with count {B a}:◎)
#  (with count {pass B}:◎)
#  (with count swap:◎)
#  (with nor {right B}:◎)
#  (with count {pre B}:◎)
#  (with nor {B : 0}:◎)
#  (with count {B : (:-1 : 1)}:◎)
#  (with {nand : B} B:◎)
#  (with nor {B if}:◎)
#  (with iff {xnor B}:◎)
#  (with count {int_max B}:◎)
#  (with xnor ints:◎)
#  (with not sum:◎)
#  (with iff {B : nat_sum}:◎)
#  (with not {B : not}:◎)
#  (with nor not:◎)
#  (with iff {B some}:◎)
#  (with not {B swap}:◎)
#  (with nor {B nand}:◎)
#  (with not {or B}:◎)
# ...

# %%
tab : ap {if (right:B):B} : read stable : L2R1.idem
# Out:
# eval.step> step 31, time:73.57/5000.00, GB:5.94/2.00, context:223, cache:34952/18517
#  (with and:)
#  (with aq:)
#  (with bool:)
#  (with float_max:)
#  (with float_min:)
#  (with float_prod:)
#  (with float_sort:)
#  (with float_sum:)
#  (with head:)
#  (with iff:)
#  (with imply:)
#  (with int_max:)
#  (with int_min:)
#  (with int_prod:)
#  (with int_sort:)
#  (with int_sum:)
#  (with is:)
#  (with nat_max:)
#  (with nat_min:)
#  (with nat_prod:)
#  (with nat_sort:)
#  (with nat_sum:)
#  (with nif:)
#  (with nor:)
#  (with null:)
#  (with or:)
#  (with ring:)
#  (with stick:)
#  (with text_sort:)
#  (with xnor:)
#  (with nat_sum stick:)
#  (with {ring : B} skip:)
#  (with ring {B isnt}:)
#  (with ring {B : ar}:)
#  (with nth1 {ring : B}:)
#  (with and hasnt:)
#  (with head {B : arg}:)
#  (with {text_sort : B} const:)
#  (with int_max {B : int_sort}:)
#  (with {nat_min : B} null:)
#  (with nat_min {domain : B}:)
#  (with {int_max : B} pass:)
#  (with {int_sort : B} =:)
# ...

# %%
count : Domain?
count : read stable : L1 
count : read stable : L2 
count : read stable : L2R1 
count : read stable : L2R1.idem
# Out:
# eval.step> step 34, time:94.13/5000.00, GB:5.94/2.00, context:223, cache:44945/83984
# 10000
# eval.step> step 10, time:279.17/5000.00, GB:5.94/2.00, context:223, cache:44949/89264
# 8148
# eval.step> step 9, time:45.72/5000.00, GB:5.97/2.00, context:223, cache:44955/89276
# 3172
# eval.step> step 9, time:10.11/5000.00, GB:5.97/2.00, context:223, cache:44961/89288
# 2942
# eval.step> step 9, time:9.10/5000.00, GB:5.97/2.00, context:223, cache:44964/89294
# 2749

# %%
count : ap {if (right:B):B} : read stable : L2R1.idem 
count : ap {nif (right:B):B} : read stable : L2R1.idem
# Out:
# eval.step> step 15, time:26.55/5000.00, GB:5.99/2.00, context:223, cache:44967/89300
# 2402
# eval.step> step 15, time:14.12/5000.00, GB:5.99/2.00, context:223, cache:44970/89307
# 347
