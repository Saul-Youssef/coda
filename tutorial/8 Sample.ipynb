# %% [markdown]
# ## Sampling the space of pure data

# %% [markdown]
# One easy way to produce sample data is with **ap const** which repeats it's arguments once for each input atom...

# %%
ap const a : 1 2 3 4 
ap const a b : 1 2 3 4 
ap const (:) : 1 2 3 4
# Out:
# a a a a
# a b a b a b a b
# ◎ ◎ ◎ ◎

# %% [markdown]
# In most sampling situations, we'll want some specified collection d1, d2, d3,.... where d1, d2, d3 are each data.  To produce a sequence like that, you don't want to produce d1 d2 d3 because concatenation destroys the sequence.  Instead, an easy solution is to produce a sequence
#
# * (:d1) (:d2) (:d3)
#
# where each data in the collection has it's own container.  We'll do a bit of this by hand...

# %%
(put : x y z ) (put : a b c )
# Out:
# (:x y z) (:a b c)

# %% [markdown]
# For convenience, **sample.odd** and **sample.even** produces even and odd sequences of the simplest atom (:) ("Hydrogen"), packaged as above...

# %%
sample.odd : 4 
sample.even : 4
# Out:
# (:◎) (:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎)
# ◎ (:◎ ◎) (:◎ ◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎ ◎)

# %% [markdown]
# The **sample.pure** operator lets one sample the whole space of pure data via
#
# * sample.pure : width depth
#
# where **width** is the maximum data length and **depth** is the maximum depth.  For example...

# %%
#
#  sample.pure : <width> <depth> 
#
tab : pure : first 10 : sample.pure : 2 2
# Out:
#  (:)
#  (:(:))
#  (:(:(:)))
#  (:(:(:)(:)))
#  (:((:):))
#  (:((:):(:)))
#  (:((:):(:)(:)))
#  (:((:)(:):))
#  (:((:)(:):(:)))
#  (:((:)(:):(:)(:)))

# %% [markdown]
# The direct approach is rarely useful because the universe of pure data grows enormously rapidly with **width** and **depth**.  So much so that
#
# * sample.pure : 2 3
#
# is already challenging for a laptop.
#
# ### Size of sample.pure versus width and depth:
#
# |         | width 1  | width 2 | width 3 | width 4  | width 5 |
# |---------|---------:|--------:|--------:|---------:|--------:|
# |depth 1  |    2     |    3    |    4    |     5    |    6    |
# |depth 2  |    5     |     91   |    4369   |   406,901    |    62,193,781    |
# |depth 3  |    26     |     68,583,243   |    ?    |     ?    |    ?    |
# |depth 4  |    677     |     ?   |    ?    |     ?    |    ?    |
# |depth 5  |    458,330     |     ?   |    ?    |     ?    |    ?    |

# %% [markdown]
# Of course, the space of pure data includes all data, meaning all mathematical/logical/computational objects.  Undecided data ("variables"), for example, already appear in sample.pure : 2 2, which you can detect by, for example counting.

# %%
ap {count : get : B} : sample.pure : 2 2
# Out:
# (count:(({get }:◎):({ B}:◎))) (count:(({get }:(:◎)):({ B}:(:◎)))) (count:(({get }:(:(:◎))):({ B}:(:(:◎))))) (count:(({get }:(:(:◎ ◎))):({ B}:(:(:◎ ◎))))) (count:(({get }:(:𝟬)):({ B}:(:𝟬)))) (count:(({get }:(:𝝞)):({ B}:(:𝝞)))) (count:(({get }:(:(◎:◎ ◎))):({ B}:(:(◎:◎ ◎))))) (count:(({get }:(:(◎ ◎:))):({ B}:(:(◎ ◎:))))) (count:(({get }:(:(◎ ◎:◎))):({ B}:(:(◎ ◎:◎))))) (count:(({get }:(:(◎ ◎:◎ ◎))):({ B}:(:(◎ ◎:◎ ◎))))) (count:(({get }:(:◎ ◎)):({ B}:(:◎ ◎)))) (count:(({get }:(:◎ (:◎))):({ B}:(:◎ (:◎))))) (count:(({get }:(:◎ (:◎ ◎))):({ B}:(:◎ (:◎ ◎))))) (count:(({get }:(:◎ 𝟬)):({ B}:(:◎ 𝟬)))) (count:(({get }:(:◎ 𝝞)):({ B}:(:◎ 𝝞)))) (count:(({get }:(:◎ (◎:◎ ◎))):({ B}:(:◎ (◎:◎ ◎))))) (count:(({get }:(:◎ (◎ ◎:))):({ B}:(:◎ (◎ ◎:))))) (count:(({get }:(:◎ (◎ ◎:◎))):({ B}:(:◎ (◎ ◎:◎))))) (count:(({get }:(:◎ (◎ ◎:◎ ◎))):({ B}:(:◎ (◎ ◎:◎ ◎))))) (count:(({get }:(:(:◎) ◎)):({ B}:(:(:◎) ◎)))) (count:(({get }:(:(:◎) (:◎))):({ B}:(:(:◎) (:◎))))) (count:(({get }:(:(:◎) (:◎ ◎))):({ B}:(:(:◎) (:◎ ◎))))) (count:(({get }:(:(:◎) 𝟬)):({ B}:(:(:◎) 𝟬)))) (count:(({get }:(:(:◎) 𝝞)):({ B}:(:(:◎) 𝝞)))) (count:(({get }:(:(:◎) (◎:◎ ◎))):({ B}:(:(:◎) (◎:◎ ◎))))) (count:(({get }:(:(:◎) (◎ ◎:))):({ B}:(:(:◎) (◎ ◎:))))) (count:(({get }:(:(:◎) (◎ ◎:◎))):({ B}:(:(:◎) (◎ ◎:◎))))) (count:(({get }:(:(:◎) (◎ ◎:◎ ◎))):({ B}:(:(:◎) (◎ ◎:◎ ◎))))) (count:(({get }:(:(:◎ ◎) ◎)):({ B}:(:(:◎ ◎) ◎)))) (count:(({get }:(:(:◎ ◎) (:◎))):({ B}:(:(:◎ ◎) (:◎))))) (count:(({get }:(:(:◎ ◎) (:◎ ◎))):({ B}:(:(:◎ ◎) (:◎ ◎))))) (count:(({get }:(:(:◎ ◎) 𝟬)):({ B}:(:(:◎ ◎) 𝟬)))) (count:(({get }:(:(:◎ ◎) 𝝞)):({ B}:(:(:◎ ◎) 𝝞)))) (count:(({get }:(:(:◎ ◎) (◎:◎ ◎))):({ B}:(:(:◎ ◎) (◎:◎ ◎))))) (count:(({get }:(:(:◎ ◎) (◎ ◎:))):({ B}:(:(:◎ ◎) (◎ ◎:))))) (count:(({get }:(:(:◎ ◎) (◎ ◎:◎))):({ B}:(:(:◎ ◎) (◎ ◎:◎))))) (count:(({get }:(:(:◎ ◎) (◎ ◎:◎ ◎))):({ B}:(:(:◎ ◎) (◎ ◎:◎ ◎))))) (count:(({get }:(:𝟬 ◎)):({ B}:(:𝟬 ◎)))) (count:(({get }:(:𝟬 (:◎))):({ B}:(:𝟬 (:◎))))) (count:(({get }:(:𝟬 (:◎ ◎))):({ B}:(:𝟬 (:◎ ◎))))) (count:(({get }:(:𝟬 𝟬)):({ B}:(:𝟬 𝟬)))) (count:(({get }:(:𝟬 𝝞)):({ B}:(:𝟬 𝝞)))) (count:(({get }:(:𝟬 (◎:◎ ◎))):({ B}:(:𝟬 (◎:◎ ◎))))) (count:(({get }:(:𝟬 (◎ ◎:))):({ B}:(:𝟬 (◎ ◎:))))) (count:(({get }:(:𝟬 (◎ ◎:◎))):({ B}:(:𝟬 (◎ ◎:◎))))) (count:(({get }:(:𝟬 (◎ ◎:◎ ◎))):({ B}:(:𝟬 (◎ ◎:◎ ◎))))) (count:(({get }:(:𝝞 ◎)):({ B}:(:𝝞 ◎)))) (count:(({get }:(:𝝞 (:◎))):({ B}:(:𝝞 (:◎))))) (count:(({get }:(:𝝞 (:◎ ◎))):({ B}:(:𝝞 (:◎ ◎))))) (count:(({get }:(:𝝞 𝟬)):({ B}:(:𝝞 𝟬)))) (count:(({get }:(:𝝞 𝝞)):({ B}:(:𝝞 𝝞)))) (count:(({get }:(:𝝞 (◎:◎ ◎))):({ B}:(:𝝞 (◎:◎ ◎))))) (count:(({get }:(:𝝞 (◎ ◎:))):({ B}:(:𝝞 (◎ ◎:))))) (count:(({get }:(:𝝞 (◎ ◎:◎))):({ B}:(:𝝞 (◎ ◎:◎))))) (count:(({get }:(:𝝞 (◎ ◎:◎ ◎))):({ B}:(:𝝞 (◎ ◎:◎ ◎))))) (count:(({get }:(:(◎:◎ ◎) ◎)):({ B}:(:(◎:◎ ◎) ◎)))) (count:(({get }:(:(◎:◎ ◎) (:◎))):({ B}:(:(◎:◎ ◎) (:◎))))) (count:(({get }:(:(◎:◎ ◎) (:◎ ◎))):({ B}:(:(◎:◎ ◎) (:◎ ◎))))) (count:(({get }:(:(◎:◎ ◎) 𝟬)):({ B}:(:(◎:◎ ◎) 𝟬)))) (count:(({get }:(:(◎:◎ ◎) 𝝞)):({ B}:(:(◎:◎ ◎) 𝝞)))) (count:(({get }:(:(◎:◎ ◎) (◎:◎ ◎))):({ B}:(:(◎:◎ ◎) (◎:◎ ◎))))) (count:(({get }:(:(◎:◎ ◎) (◎ ◎:))):({ B}:(:(◎:◎ ◎) (◎ ◎:))))) (count:(({get }:(:(◎:◎ ◎) (◎ ◎:◎))):({ B}:(:(◎:◎ ◎) (◎ ◎:◎))))) (count:(({get }:(:(◎:◎ ◎) (◎ ◎:◎ ◎))):({ B}:(:(◎:◎ ◎) (◎ ◎:◎ ◎))))) (count:(({get }:(:(◎ ◎:) ◎)):({ B}:(:(◎ ◎:) ◎)))) (count:(({get }:(:(◎ ◎:) (:◎))):({ B}:(:(◎ ◎:) (:◎))))) (count:(({get }:(:(◎ ◎:) (:◎ ◎))):({ B}:(:(◎ ◎:) (:◎ ◎))))) (count:(({get }:(:(◎ ◎:) 𝟬)):({ B}:(:(◎ ◎:) 𝟬)))) (count:(({get }:(:(◎ ◎:) 𝝞)):({ B}:(:(◎ ◎:) 𝝞)))) (count:(({get }:(:(◎ ◎:) (◎:◎ ◎))):({ B}:(:(◎ ◎:) (◎:◎ ◎))))) (count:(({get }:(:(◎ ◎:) (◎ ◎:))):({ B}:(:(◎ ◎:) (◎ ◎:))))) (count:(({get }:(:(◎ ◎:) (◎ ◎:◎))):({ B}:(:(◎ ◎:) (◎ ◎:◎))))) (count:(({get }:(:(◎ ◎:) (◎ ◎:◎ ◎))):({ B}:(:(◎ ◎:) (◎ ◎:◎ ◎))))) (count:(({get }:(:(◎ ◎:◎) ◎)):({ B}:(:(◎ ◎:◎) ◎)))) (count:(({get }:(:(◎ ◎:◎) (:◎))):({ B}:(:(◎ ◎:◎) (:◎))))) (count:(({get }:(:(◎ ◎:◎) (:◎ ◎))):({ B}:(:(◎ ◎:◎) (:◎ ◎))))) (count:(({get }:(:(◎ ◎:◎) 𝟬)):({ B}:(:(◎ ◎:◎) 𝟬)))) (count:(({get }:(:(◎ ◎:◎) 𝝞)):({ ...

# %% [markdown]
# ### Practical searching
#
# Although **sample.pure** samples all pure data and, therefore, all mathematical objects, these samples are typically far too huge to be practically helpful.  Instead, the operator **sample.data** is much more practical.  This operation works by providing a sequence of codas and a width.
#
# * sample.data <...sequence of codas..> : width
#
# A few examples will illustrate.

# %%
#
#   Just one argument coda "a" and width <= 5 gives 
#
sample.data a : 5
# Out:
# ◎ (:a a a a) (:a a a a a) (:a) (:a a) (:a a a)

# %%
#
#   Note that the sample is delivered, as usual, as (:data1) (:data2) ... 
#
#   If you provide two codas, a and b, all permutations are included. 
#
sample.data a b : 5
# Out:
# (:a b b b b) (:a b b b a) (:b b b a b) (:a a b a) (:b a b b a) (:b b b b a) (:b a b) ◎ (:b a b a) (:b a b a a) (:a b a) (:b b b a) (:a a) (:b b b a a) (:a a a a b) (:b b a b b) (:a b a b) (:a a b a a) (:a b a a b) (:b a a b) (:b b a a b) (:a b) (:a a a a) (:b b b b b) (:a a a b a) (:b a) (:a a a) (:b a a b a) (:a a b b b) (:b a a b b) (:b b) (:b b b) (:b a a a a) (:b b a a) (:a b b a b) (:b a b a b) (:a a b a b) (:a b b a) (:a b b b) (:a b b a a) (:a a a b) (:b a a) (:b b b b) (:b a a a b) (:b a b b b) (:a b a b a) (:b) (:a) (:b b a a a) (:a b b) (:a b a b b) (:b b a b a) (:b a a a) (:b b a b) (:b a b b) (:b b a) (:a b a a) (:a b a a a) (:a a b) (:a a b b a) (:a a a b b) (:a a a a a) (:a a b b)

# %%
#
#   You can add language literals <A> and <B> and a special symbol <{$}> to create language expressions.
#
sample.data <A> <B> <{$}> a b (defs:Basic) : 2
# Out:
# (:star) (:sum {B : if}) (:pass {is B}) (:pass {const B}) (:{B : bin} B) (:B {B isnt}) (:star {B : star}) (:{B sum} pass) (:{B : if} a) (:if {B null}) (:isnt {B : pass}) (:{null B} star) (:{pass : B} if) (:{nif : B} A) (:{B : if} left) (:put {b B}) (:left {isnt : B}) (:const {B star}) (:{B : get} sum) (:hasnt {B : arg}) (:{B sum} plus) (:{prod : B} const) (:{sum B} has) (:left {const : B}) (:{B : isnt} null) (:{prod B} b) (:get {B}) (:{B : nif} star) (:{B const} if) (:sum {B const}) (:pass A) (:{is : B} B) (:{null B} a) (:{B plus} get) (:{domain B} const) (:star {B prod}) (:plus {B null}) (:star {B : hasnt}) (:{plus B} has) (:null {B : domain}) (:{B is} A) (:A {get B}) (:is {a : B}) (:{null : B} put) (:{has : B} arg) (:{prod B} bin) (:{B nif} right) (:{left : B} get) (:{prod : B} right) (:prod {B isnt}) (:{left B} a) (:{prod : B} get) (:{left : B} B) (:const {B : star}) (:has {B : plus}) (:B {left B}) (:{b : B} B) (:if get) (:isnt {B prod}) (:{has : B} star) (:bin has) (:{right B} left) (:hasnt {B A}) (:{nif : B}) (:{B : b} B) (:has {B : a}) (:{B null} if) (:is {sum B}) (:{B : A} isnt) (:{arg : B} prod) (:sum {nif : B}) (:{B star} right) (:bin {B left}) (:if {B isnt}) (:hasnt {B : nif}) (:hasnt {a B}) (:{B : domain} isnt) (:star {has : B}) (:has B) (:domain null) (:null {domain B}) (:null {B pass}) (:{B : pass} hasnt) (:b {B : domain}) (:{star B} b) (:{right B} const) (:const {B isnt}) (:star {B : null}) (:{null B} b) (:nif {left B}) (:{if B} null) (:{B arg} has) (:{B : left} plus) (:bin {right B}) (:right arg) (:{const B} right) (:{B : has} left) (:isnt {B b}) (:{null : B} bin) (:isnt {B : put}) (:{B : prod} left) (:{A B} put) (:plus {B : arg}) (:B {A B}) (:{isnt B} B) (:{get B} get) (:put {B domain}) (:{B a} null) (:left {B : has}) (:arg {pass : B}) (:{get B} plus) (:{b : B} a) (:{B : isnt} bin) (:{const B} is) (:domain {left : B}) (:{nif : B} null) (:hasnt {a : B}) (:{B hasnt}) (:hasnt {B arg}) (:domain {B get}) (:right {has B}) (:{put B} B) (:const {hasnt B}) (:null {B : plus}) (:{has : B} if) (:{bin : B} plus) (:{if B} hasnt) (:{B : b} isnt) (:{B : nif} plus) (:{A B}) (:{B : a} left) (:star {B isnt}) (:{star B} plus) (:{B domain} arg) (:{pass : B} A) (:isnt {B : prod}) (:nif {B null}) (:{B plus} has) (:{nif : B} nif) (:{has : B}) (:pass {domain B}) (:put {put B}) (:{B : a} bin) (:{B : get} left) (:b {B : null}) (:{B const} prod) (:{left : B} a) (:const {A B}) (:b A) (:right {star B}) (:A {B : has}) (:is left) (:plus B) (:{B b} is) (:const {nif : B}) (:{bin : B} put) (:arg {B : a}) (:{plus B} isnt) (:star {B : A}) (:{B sum} right) (:{plus B} hasnt) (:{B : put} b) (:arg {B domain}) (:{right B} star) (:b {right B}) (:pass {star : B}) (:get arg) (:bin {domain : B}) (:put null) (:B {B : left}) (:get {B : hasnt}) (:{B domain} hasnt) (:prod {plus : B}) (:left const) (:{B : plus} null) (:hasnt {B right}) (:put {put : B}) (:{B : nif} domain) (:{B if} nif) (:b left) (:{right : B} B) (:{B : has}) (:{domain B} B) (:B {B : isnt}) (:{B : star} put) (:has {is : B}) (:has {B nif}) (:{sum B} get) (:null {null B}) (:A B) (:isnt sum) (:{B : sum} get) (:left {right : B}) (:{B : bin} if) (:prod A) (:const {plus B}) (:{sum B} bin) (:A {B : const}) (:b a) (:{get B} right) (:{B : b} left) (:{B : const} a) (:{B : right} a) (:{sum : B} put) (:domain {get B}) (:is plus) (:get {pass : B}) (:b put) (:pass {a : B}) (:{A : B} left) (:{hasnt B} hasnt) (:{B prod}) (:const isnt) (:has {sum : B}) (:right {a B}) (:if {left : B}) (:{B plus} is) (:{plus : B}) (:b {B left}) (:{is : B} hasnt) (:{arg B} A) (:bin {B : hasnt}) (:{nif B}) (:arg {B : pass}) (:right {B sum}) (:prod b) (:b isnt) (:{pass B} null) (:{plus : B} B) (:pass nif) (:{B hasnt} sum) (:{a : B} has) (:domain {B arg}) (:arg {bin B}) (:{B get}) (:put prod) (:nif {B : put}) (:star domain) (:{a B} bin) (:pass {B : is}) (:null {B : sum}) (:{hasnt : B} prod) (:b {B : star}) (:get {hasnt B}) (:{pass B} b) (:{isnt : B} nif) (:B {a B}) (:null {B plus}) (:left {B}) (:if null) (:get {right : B}) (:put star)  ...

# %%
#
#   To meaningfully search, one should add domains representing established definitions.  To do this, first see 
#   all currently available definitions like so...
#
defs:
# Out:
# = Def Let ab allcodes alphabet and ap apby aq ar arg as assign bin bool by cache.clear cache.reset cases co coda codes collect const count d2s def defaultTime defs demo digits dir do do1 dom domain domulti down down1 endswith equal equiv eval first float_div float_inv float_max float_min float_prod float_sort float_sum floats get has hasnt head help home if iff imply import info int_div int_inv int_max int_min int_prod int_sort int_sum ints is isnt join ker kernel language last left let letters localdef log logging logs module more multi name nand nat nat_max nat_min nat_prod nat_sort nat_sum nats nchar nif nor not nth nth1 null once or pass pause permutation plus post pre printable prod pure put read readpath rep rev right ring s2d sample.atom sample.data sample.even sample.odd sample.pure sample.window skip some source sources split star startswith stat stata step stick sum swap tab tail term text_sort theorem uni up up1 use use1 with wrap write xnor xor ◎ 𝝞 𝟬

# %%
#
#    Each definition is in a "module" which is either a python file (.py) or a coda file (.co). 
#
once : module : defs:
# Out:
# Logic  Define Apply Text Basic Variable Sequence Evaluation Search Source Collect IO Help Evaluate Path Number Import Language Log Time Sample

# %%
#
#    Typically one would want some but not all definitions for a search.  For instance, one typically doesn't want to search 
#    over IO operations or Sample operations (to avoid recursion) or over help system operations.  A typical choice is...
#
defs : Apply Basic Logic Number Sequence
# Out:
# = ab and ap apby aq ar arg as bin bool by co const count domain equal first float_div float_inv float_max float_min float_prod float_sort float_sum floats get has hasnt head if iff imply int_div int_inv int_max int_min int_prod int_sort int_sum ints is isnt ker kernel last left nand nat nat_max nat_min nat_prod nat_sort nat_sum nats nif nor not nth nth1 null once or pass plus post pre prod put rep rev right ring skip some star stick sum swap tail text_sort xnor xor

# %%
sample.data (defs:Basic) : 2
# Out:
# (:is sum) (:is prod) (:domain nif) (:if left) (:put null) (:star null) (:left domain) (:pass sum) (:has arg) (:get get) (:pass star) (:if nif) (:has star) (:left is) (:plus pass) (:put domain) (:bin bin) (:put bin) (:is get) (:right star) (:get put) (:put hasnt) (:prod isnt) (:plus is) (:sum bin) (:isnt get) (:arg) (:nif plus) (:domain has) (:left has) (:right hasnt) (:const plus) (:get null) (:put isnt) (:put get) (:get nif) (:left prod) (:nif star) (:domain prod) (:is has) (:domain) (:star has) (:put put) (:left bin) (:if) (:null domain) (:domain plus) (:const if) (:isnt pass) (:nif arg) (:left sum) (:const const) (:domain put) (:arg isnt) (:if has) (:plus isnt) (:if if) (:hasnt left) (:if const) (:if right) (:right) (:plus const) (:nif) (:put arg) (:has sum) (:prod prod) (:sum left) (:isnt) (:sum is) (:left get) (:put prod) (:const pass) (:right has) (:get plus) (:domain get) (:is arg) (:null) (:arg get) (:domain is) (:prod const) (:has has) (:left arg) (:left right) (:bin nif) (:pass has) (:star) (:isnt star) (:const bin) (:isnt sum) (:prod if) (:hasnt right) (:prod bin) (:if sum) (:sum pass) (:plus bin) (:sum plus) (:arg sum) (:sum prod) (:const sum) (:is bin) (:const put) (:null prod) (:right if) (:has null) (:if prod) (:const right) (:put) (:sum right) (:hasnt is) (:get domain) (:right get) (:left hasnt) (:star get) (:hasnt nif) (:is star) (:get star) (:arg if) (:put right) (:hasnt domain) (:put left) (:if get) (:has bin) (:right null) (:prod star) (:null nif) (:pass get) (:is) (:bin pass) (:is isnt) (:get right) (:star put) (:right pass) (:right bin) (:domain pass) (:get) (:domain hasnt) (:null is) (:domain domain) (:domain const) (:plus star) (:isnt put) (:nif has) (:bin star) (:hasnt const) (:null sum) (:hasnt null) (:right put) (:isnt arg) (:nif const) (:if pass) (:isnt left) (:const arg) (:if star) (:arg pass) (:is nif) (:prod null) (:const isnt) (:arg left) (:nif is) (:pass prod) (:sum if) (:pass domain) (:plus domain) (:star isnt) (:null arg) (:plus right) (:bin isnt) (:left const) (:domain arg) (:domain star) (:left null) (:star domain) (:isnt if) (:has const) (:prod) (:nif get) (:hasnt prod) (:left plus) (:bin sum) (:domain if) (:isnt prod) (:plus left) (:star prod) (:pass) (:star nif) (:has plus) (:bin left) (:pass const) (:get if) (:right sum) (:nif prod) (:plus put) (:const get) (:nif domain) (:prod pass) (:put plus) (:prod nif) (:is domain) (:const star) (:nif left) (:nif put) (:put is) (:right const) (:plus null) (:left put) (:star is) (:null pass) (:star sum) (:put nif) (:plus arg) (:pass nif) (:pass is) ◎ (:left isnt) (:star bin) (:has nif) (:get isnt) (:arg is) (:sum arg) (:domain sum) (:hasnt has) (:plus hasnt) (:isnt bin) (:null put) (:right is) (:pass left) (:nif hasnt) (:right arg) (:if put) (:prod right) (:prod domain) (:const hasnt) (:plus if) (:is const) (:nif null) (:plus prod) (:get sum) (:get pass) (:null hasnt) (:has domain) (:hasnt) (:prod has) (:bin hasnt) (:star hasnt) (:isnt has) (:has right) (:left left) (:bin prod) (:arg domain) (:domain right) (:isnt isnt) (:bin arg) (:sum domain) (:bin right) (:if is) (:arg bin) (:arg arg) (:plus get) (:const) (:star star) (:star plus) (:arg hasnt) (:right right) (:null star) (:right plus) (:hasnt hasnt) (:if null) (:left star) (:right isnt) (:hasnt bin) (:nif isnt) (:isnt right) (:null has) (:isnt domain) (:arg right) (:nif nif) (:get hasnt) (:put pass) (:arg prod) (:prod hasnt) (:star left) (:hasnt get) (:sum get) (:hasnt star) (:const has) (:has put) (:get left) (:if domain) (:arg plus) (:sum hasnt) (:null if) (:has if) (:hasnt sum) (:bin is) (:isnt hasnt) (:plus sum) (:star const) (:isnt nif) (:pass put) (:isnt plus) (:get prod) (:get bin) (:is plus) (:isnt const) (:pass bin) (:is left) (:get has) (:prod sum) (:hasnt plus) (:pass isnt) (:pass if) (:sum) (:prod is) (:null isnt) (:nif bin) (:has) (:if isnt) (:bin get) (:isnt is) (:bin if) (:bin put) (:nif pass) (:arg const) (:left pass) (:has left) (:domain null) (:sum has) (:hasnt if) (:get const)  ...

# %%
count : defs : Sequence
# Out:
# 15

# %%
sample.data (defs:Sequence) : 2
# Out:
# (:rev once) (:head count) (:count rev) (:once rev) (:by swap) (:once nth1) (:nth1 nth1) (:first head) (:skip by) (:nth once) (:first last) (:by last) (:head head) (:nth1 post) (:tail once) (:nth1 tail) (:swap first) (:by nth) (:head nth) (:swap nth) (:head skip) (:head once) (:swap post) (:rep pre) (:first count) (:swap last) (:once) (:post tail) (:once swap) (:nth1 rev) (:once head) (:first by) (:nth1 first) (:nth) (:swap skip) (:skip tail) (:post skip) (:nth1 once) (:post by) (:head post) (:last nth) (:last count) (:count first) (:pre once) (:nth1 pre) (:pre) (:rep head) (:last first) (:pre post) (:count post) (:tail nth) (:nth post) (:by count) (:once post) (:rep skip) (:nth skip) (:nth last) (:rep post) (:last once) (:pre tail) (:first nth1) (:first skip) (:nth count) (:first post) (:pre first) (:skip swap) (:count tail) (:post count) (:tail rep) (:rep rev) (:pre swap) (:skip skip) (:tail last) (:head first) (:tail pre) (:nth nth1) (:once skip) (:count nth1) (:count swap) (:post rev) (:count count) (:last by) (:skip first) (:last last) (:once rep) (:head rev) (:rev skip) (:tail swap) (:count nth) (:last pre) (:tail skip) (:nth1) (:first nth) (:pre rev) (:tail nth1) (:first first) (:count once) (:tail count) (:swap rev) (:nth tail) (:count pre) (:rev pre) (:by rev) (:first once) (:rep swap) (:rep count) (:last rep) (:head swap) (:once by) (:pre head) (:swap count) (:by nth1) (:count) (:swap by) (:once first) (:by head) (:once nth) (:nth1 nth) (:first tail) (:rev last) (:by) (:head pre) (:tail by) (:nth nth) (:pre pre) (:tail rev) (:by pre) (:last) (:head rep) (:rev rev) (:skip nth) (:rep by) (:nth first) (:last skip) (:rep first) (:once pre) (:nth by) (:count last) (:post rep) (:swap swap) (:rep tail) (:by post) (:nth1 rep) (:nth1 last) (:swap nth1) (:nth1 count) (:nth rep) (:last swap) (:rev head) (:post first) (:head tail) (:by first) (:head nth1) (:nth1 by) (:first pre) (:by tail) (:tail tail) (:tail post) (:by once) (:post) (:first rep) (:nth1 skip) (:rev nth) (:post once) (:pre skip) (:rev rep) (:pre last) (:skip) (:pre nth1) (:last rev) (:swap) (:rep nth1) (:tail head) (:rev swap) (:skip rep) (:swap once) (:by skip) (:pre rep) (:nth head) (:last post) (:post head) (:rep once) (:head) (:skip last) (:by rep) (:rev by) (:once last) (:once once) (:skip count) (:count rep) (:count by) (:skip pre) (:post nth1) (:post nth) (:skip rev) (:nth1 swap) (:first swap) ◎ (:nth rev) (:swap head) (:rep rep) (:rev) (:nth1 head) (:once count) (:rep) (:rev first) (:rev post) (:pre nth) (:nth swap) (:tail) (:rev tail) (:tail first) (:swap rep) (:post post) (:skip nth1) (:count head) (:head last) (:post swap) (:count skip) (:swap tail) (:post last) (:rev count) (:last nth1) (:once tail) (:pre count) (:skip once) (:first) (:first rev) (:nth pre) (:post pre) (:by by) (:rep nth) (:skip post) (:pre by) (:rev nth1) (:head by) (:last tail) (:swap pre) (:rep last) (:skip head) (:last head)

# %%
defs:Sequence
# Out:
# by count first head last nth nth1 once post pre rep rev skip swap tail

# %%
sample.data rev first tail last skip rep nth1 once count nth pre post : 2
# Out:
# (:tail post) (:count count) (:nth1 nth) (:nth count) (:pre nth) (:first) (:pre first) (:skip rep) (:post rep) (:tail count) (:tail rev) (:count post) (:pre skip) (:first last) (:last) (:skip pre) (:rep skip) (:last post) (:nth1 skip) (:count once) (:pre) (:once rev) (:nth nth1) (:tail) (:first pre) (:rev pre) (:last pre) (:pre last) (:skip first) (:tail skip) (:once nth) (:nth1) (:rep tail) (:once tail) (:nth rep) (:once count) (:post skip) (:rep nth) (:rev skip) ◎ (:post nth1) (:pre nth1) (:nth1 tail) (:rep rep) (:nth pre) (:count tail) (:nth nth) (:first nth1) (:tail nth1) (:post once) (:pre tail) (:count pre) (:skip last) (:rep first) (:skip once) (:nth rev) (:skip count) (:tail tail) (:tail last) (:pre pre) (:post post) (:once first) (:pre rev) (:once last) (:post rev) (:count last) (:first nth) (:skip post) (:post) (:nth last) (:nth skip) (:nth tail) (:rev nth1) (:first post) (:nth once) (:skip skip) (:tail first) (:rev last) (:rev first) (:nth1 post) (:nth first) (:post first) (:skip tail) (:rep once) (:once rep) (:tail nth) (:last rev) (:rev rev) (:first rep) (:rep) (:nth) (:last skip) (:nth1 rep) (:rev tail) (:last once) (:rep pre) (:rev) (:rev count) (:first count) (:skip nth1) (:count skip) (:once once) (:rep last) (:count nth) (:nth1 pre) (:skip nth) (:nth1 rev) (:last rep) (:last first) (:once) (:rep post) (:last last) (:count rev) (:first rev) (:once post) (:first tail) (:post pre) (:rep rev) (:pre rep) (:rep count) (:rev post) (:post last) (:count nth1) (:pre count) (:tail pre) (:pre once) (:nth1 last) (:first first) (:skip) (:rev once) (:rev nth) (:last count) (:tail rep) (:last nth1) (:once nth1) (:first once) (:post count) (:count) (:tail once) (:post nth) (:once skip) (:last nth) (:count first) (:nth1 first) (:skip rev) (:post tail) (:once pre) (:nth1 nth1) (:nth1 count) (:last tail) (:count rep) (:rep nth1) (:first skip) (:nth1 once) (:rev rep) (:nth post) (:pre post)

# %%
#
#    To create a typical sample, we start with A, B and {$} for language purposes, add a few "variables" (x? y? z?) and 
#    mix in the above definitions. 
#    
sample.data <A> <B> x? y? <{$}> (defs:Apply Basic) : 2
# Out:
# (:{B : left} right) (:pass {B : (y:)}) (:bin {B get}) (:sum {bin : B}) (:if {apby : B}) (:apby {const B}) (:kernel get) (:right) (:is {B : ab}) (:null {kernel : B}) (:right {sum B}) (:prod {ker B}) (:null {nif B}) (:{B nif} co) (:has B) (:right ker) (:{ker B} plus) (:has const) (:if {B star}) (:(y:) {arg : B}) (:const {B : is}) (:ap {(x:) : B}) (:{B : pass} put) (:{B : plus} isnt) (:{B as} isnt) (:is {domain B}) (:has {domain : B}) (:nif {B nif}) (:ap pass) (:{B arg} prod) (:{B : bin} get) (:aq {B left}) (:{B : left} const) (:has {as : B}) (:(x:) {B : domain}) (:{sum : B} const) (:B {apby : B}) (:apby {B is}) (:{B pass} star) (:{put B} plus) (:{pass B} right) (:{B : ap} isnt) (:null put) (:is null) (:(x:) kernel) (:nif {plus : B}) (:{B : right} B) (:has {plus : B}) (:{has : B} B) (:const {B : domain}) (:{B : (y:)} kernel) (:put prod) (:left {is B}) (:{(y:) : B} is) (:kernel {isnt B}) (:has {B const}) (:{ap : B} get) (:put {B : domain}) (:{B : ab} get) (:has {B : prod}) (:has {pass : B}) (:{bin : B} bin) (:{(x:) : B} has) (:{plus : B} const) (:{is : B} has) (:(y:) co) (:{B prod} domain) (:co {A : B}) (:{bin B} const) (:ar {B : as}) (:A {(x:) : B}) (:arg right) (:(x:) bin) (:const {is : B}) (:{A B} get) (:domain bin) (:{B get} left) (:nif pass) (:aq {B}) (:{nif B} star) (:{B : bin} (y:)) (:{ar : B} right) (:{domain : B} apby) (:A {get B}) (:{const B} co) (:{hasnt B} put) (:sum {B : ar}) (:ar {B : plus}) (:{B : left} A) (:arg bin) (:{get B} pass) (:{ker B} pass) (:hasnt {apby : B}) (:right {B : kernel}) (:{isnt B} has) (:{B co} plus) (:{isnt B} right) (:null {pass B}) (:{B get} ap) (:{B : const} ap) (:{B const} ar) (:{if : B} ap) (:{B hasnt} left) (:(y:) {bin : B}) (:bin {B : is}) (:{B : if} pass) (:{B : co} if) (:{B : get} A) (:aq {B : is}) (:(y:) {B : ar}) (:as isnt) (:star {B domain}) (:{B : as} is) (:{B null} right) (:aq put) (:{nif : B} star) (:{B : star} left) (:kernel {aq : B}) (:{B null} plus) (:{right B} bin) (:ab {sum : B}) (:{ar B} plus) (:co {ab : B}) (:{B : apby} nif) (:pass {B : get}) (:plus hasnt) (:ar {B : kernel}) (:{B : aq} star) (:bin {B apby}) (:{as B} sum) (:{B is} sum) (:{domain : B} A) (:{bin B} A) (:{B null} isnt) (:apby {isnt : B}) (:{is B} nif) (:{B null} ar) (:apby {B arg}) (:{B : sum} pass) (:(y:) {prod : B}) (:get {ker B}) (:sum {ap B}) (:left arg) (:{kernel : B} star) (:{has B} has) (:ker apby) (:sum {B : has}) (:co {co B}) (:{B sum} kernel) (:{B arg} domain) (:{B co} (y:)) (:if {B domain}) (:get {A : B}) (:ker {B nif}) (:{B right} plus) (:hasnt arg) (:{left : B} (x:)) (:as {B : nif}) (:{const B} has) (:plus {left B}) (:{plus B} const) (:{pass B} B) (:hasnt {A B}) (:right {B : arg}) (:{as B} aq) (:{kernel B} hasnt) (:ap {get B}) (:pass bin) (:A prod) (:co sum) (:{B : left} ker) (:ar {B as}) (:{B : arg} has) (:left {B get}) (:ker {B : prod}) (:{ab : B} domain) (:{B star} ab) (:isnt {B : A}) (:{aq : B} hasnt) (:{nif : B} prod) (:{B : get} (y:)) (:aq {B arg}) (:has null) (:nif {B arg}) (:star {ap : B}) (:{B : ap} domain) (:domain {B null}) (:star {B ker}) (:{B : apby} (x:)) (:null {is : B}) (:sum {B if}) (:co {B null}) (:{B prod} null) (:{(x:) B} ker) (:has {is : B}) (:domain {sum : B}) (:isnt {co : B}) (:{B} has) (:prod {has B}) (:star {right : B}) (:{plus : B} kernel) (:is {put : B}) (:{if : B} B) (:{nif : B} kernel) (:{(y:) B} (x:)) (:right {const B}) (:arg {B : bin}) (:{B arg} right) (:{B as} A) (:{nif B} is) (:ap {B : aq}) (:right {ker : B}) (:{B : sum} ab) (:(x:) {bin : B}) (:{isnt B} apby) (:{ab : B} if) (:is co) (:null {B : has}) (:right {B : ap}) (:B {co : B}) (:{B : null} as) (:{B nif} arg) (:A {arg B}) (:prod {B is}) (:{B star} ar) (:{B : ker} isnt) (:kernel {domain B}) (:prod {right B}) (:nif ap) (:{B get} get) (:{B isnt} co) (:plus sum) (:isnt {B bin}) (:{star : B} is) (:kernel {isnt : B}) (:(y:) has) (:{sum : B} A) (:{put B} apby) (:(x:) {A B}) (:{B as}) (:plus {B : plus}) (:{aq : B} (y:)) (:if {B ar}) (:{B aq} B) (:{B A} hasnt) (:bin {B : A}) (:prod ap) (:left {const B}) (:(y:) {B (x:)})  ...

# %%
Let Sample : sample.data <A> <B> x? y? <{$}>  : 2

# %%
#
#   sample? is then a collection of data that can be used, for instance, to test for theorems or search for 
#   algebraic structures of interest, as shown in study tutorials. 
#
count : Sample?
# Out:
# 138

# %% [markdown]
# For larger scale searching, one would typically increase from width=2 and search in parallel and, perhaps add more variables.
#
# This can be useful for theorem testing and for searching for algebraic structures of interest as illustrated in the theorem tutorial and in various study notebooks.
