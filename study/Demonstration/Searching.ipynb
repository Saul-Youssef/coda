# %%
defaultTime:100
# Out:
# (defaultTime:100)
# /Users/youssef/coda/study/Classify.co /Users/youssef/coda/study/Order /Users/youssef/coda/study/Algebra.co /Users/youssef/coda/study/Demonstration /Users/youssef/coda/study/Classify /Users/youssef/coda/study/Probability /Users/youssef/coda/study/zzzarchive /Users/youssef/coda/study/STUDIES.md /Users/youssef/coda/study/Natural.co /Users/youssef/coda/study/Algebraic /Users/youssef/coda/study/Search /Users/youssef/coda/study/Number /Users/youssef/coda/study/Short.co /Users/youssef/coda/study/Paradoxes /Users/youssef/coda/study/.ipynb_checkpoints /Users/youssef/coda/study/Space /Users/youssef/coda/study/Reference /Users/youssef/coda/study/Algebra /Users/youssef/coda/study/Search.co /Users/youssef/coda/study/SNAP_CLUB.pdf

# %%
#
#   Import convenient search spaces
#
import : endswith Search.co : dir : up : .

# %%
S0?
# Out:
# (:0) (:1) ◎ (:0 1)

# %%
tab : C2?:
# Out:
#  (:B {0 : B})
#  (:{B : domain} put)
#  (:depth {put : B})
#  (:{B isnt} hasnt)
#  (:nif {B : bin})
#  (:{B : arg} put)
#  (:{pass B} if)
#  (:{is : B} B)
#  (:plus {0 B})
#  (:b {B : star})
#  (:has {sum : B})
#  (:B a)
#  (:0 {B b})
#  (:isnt nif)
#  (:A {B left})
#  (:{B star} const)
#  (:b {domain : B})
#  (:arg {right B})
#  (:{B : plus} a)
#  (:has {is : B})
#  (:b {b B})
#  (:has {if : B})
#  (:{pass : B})
#  (:0 {right : B})
#  (:is a)
#  (:{star : B} b)
#  (:domain {A B})
#  (:{B depth} sum)
#  (:{B has} right)
#  (:{domain : B} 0)
#  (:{B : prod} a)
#  (:{B isnt} depth)
#  (:b B)
#  (:{B depth} put)
#  (:1 A)
#  (:{B : right} A)
#  (:plus {B : A})
#  (:a depth)
#  (:has {has : B})
#  (:{1 : B} b)
#  (:left {domain B})
#  (:depth {0 B})
#  (:domain {star : B})
#  (:domain {B : arg})
#  (:right {B : arg})
#  (:nif {plus B})
#  (:domain {is : B})
#  (:plus {B : arg})
#  (:{star B} 0)
#  (:{depth B} b)
#  (:{B prod} 0)
#  (:get {if : B})
#  (:put {B : nif})
#  (:{A B} plus)
# ...

# %%
count : C2?:
# Out:
# 6532

# %%
count : C3?:
# Out:
# 76082

# %%
eval 1000 : count : C13?:
# Out:
# 76168

# %%
eval 1000 : tab : first 10 : skip 100 : C13?:

# %%
help : sample.data
# Out:
# code:
#     sample.data
# module:
#     Sample
# summary:
#     Get a sample of even and odd atoms.
# description:
# path:
#     /Users/youssef/coda/py/Sample.py
# demos:
#     1. sample.even : 5
#     2. sample.odd  : 5
#     3. sample.atom : 5
#     4. count : sample.atom : 10
#     5. sample.pure : 2 2
#     6. sample.data a : 5
#     7. sample.data a b : 5
#     8. sample.data <A> <B> <{$}> a : 3
#     9. sample.data <A> <B> <{$}> (defs:Apply Basic Logic Number Sequence) : 2

# %%
sample.data a b : 5
# Out:
# (:b b a b a) (:a b a a b) (:b a a b a) (:a b a a) (:a b b b) (:b a a) (:a b b a b) (:b b a a a) (:a b b) (:b b a) (:a b) (:b a b) (:a b b a) (:b b b a) (:b b) (:a) (:a b b a a) (:a a a a a) (:b b b a b) (:a b a b) (:a a a b) (:a a a b b) (:a a a b a) (:a b a b a) (:a b a a a) (:a a a a b) (:b a b b a) (:b a b b) ◎ (:b a a a) (:b a) (:b a b b b) (:a a a) (:b) (:a a b b a) (:b b a b b) (:a a) (:a a b) (:a a a a) (:b b a a) (:a a b b b) (:a b a b b) (:b a b a b) (:a a b a) (:b a a a b) (:b b b b b) (:b a b a a) (:a a b a b) (:b a a b) (:b b a b) (:b b b b a) (:b b b b) (:a b b b b) (:b a b a) (:a b a) (:b a a a a) (:b b b) (:b b b a a) (:a a b b) (:a a b a a) (:b a a b b) (:b b a a b) (:a b b b a)
