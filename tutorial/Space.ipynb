# %% [markdown]
# ## Exercise of the Space.py module

# %%
from base import *

# %%
import Space

# %%
W = Space.Window(2,2)

# %%
W
# Out:
# eval: False, true: 1, false:90, undecided:0, codas:9, datas:91

# %%
for d in W: print(d)
# Out:
# ◎
# (:◎)
# (:◎ ◎)
# 𝟬
# 𝝞
# ◎◎
#
# ◎
# ◎◎
# ◎ ◎
# ◎ (:◎)
# ◎ (:◎ ◎)
# ◎ 𝟬
# ◎ 𝝞
# ◎ ◎◎
# ◎
# ◎ ◎
# ◎ ◎◎
# (:◎) ◎
# (:◎) (:◎)
# (:◎) (:◎ ◎)
# (:◎) 𝟬
# (:◎) 𝝞
# (:◎) ◎◎
# (:◎)
# (:◎) ◎
# (:◎) ◎◎
# (:◎ ◎) ◎
# (:◎ ◎) (:◎)
# (:◎ ◎) (:◎ ◎)
# (:◎ ◎) 𝟬
# (:◎ ◎) 𝝞
# (:◎ ◎) ◎◎
# (:◎ ◎)
# (:◎ ◎) ◎
# (:◎ ◎) ◎◎
# 𝟬 ◎
# 𝟬 (:◎)
# 𝟬 (:◎ ◎)
# 𝟬 𝟬
# 𝟬 𝝞
# 𝟬 ◎◎
# 𝟬
# 𝟬 ◎
# 𝟬 ◎◎
# 𝝞 ◎
# 𝝞 (:◎)
# 𝝞 (:◎ ◎)
# 𝝞 𝟬
# 𝝞 𝝞
# 𝝞 ◎◎
# 𝝞
# 𝝞 ◎
# 𝝞 ◎◎
# ◎◎ ◎
# ◎◎ (:◎)
# ◎◎ (:◎ ◎)
# ◎◎ 𝟬
# ◎◎ 𝝞
# ◎◎ ◎◎
# ◎◎
# ◎◎ ◎
# ◎◎ ◎◎
#  ◎
#  (:◎)
#  (:◎ ◎)
#  𝟬
#  𝝞
#  ◎◎
#
#  ◎
#  ◎◎
# ◎ ◎
# ◎ (:◎)
# ◎ (:◎ ◎)
# ◎ 𝟬
# ◎ 𝝞
# ◎ ◎◎
# ◎
# ◎ ◎
# ◎ ◎◎
# ◎◎ ◎
# ◎◎ (:◎)
# ◎◎ (:◎ ◎)
# ◎◎ 𝟬
# ◎◎ 𝝞
# ◎◎ ◎◎
# ◎◎
# ◎◎ ◎
# ◎◎ ◎◎

# %%
W.eval(100,10)
# Out:
# eval: True, true: 1, false:90, undecided:0, codas:9, datas:91

# %%
W.lstat()
# Out:
# (1, 90, 0)

# %%
W.distance(W)
# Out:
# 0.02173650525298877

# %%
W.distance(Space.OddAtoms(100)+Space.EvenAtoms(100))
# Out:
# 0.01587912087912088

# %%
Even = Space.EvenAtoms(10); Odd = Space.OddAtoms(10); Atoms = Even + Odd

# %%
for d in Atoms: print(d)
# Out:
# ◎ ◎
# ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎
# ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎
# ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎

# %%
for d in Even.idempotent(data()): print(d)
# Out:
# (= ◎:(:◎))
# (= (:◎ ◎):(:(:◎ ◎)))
# (= (:◎ ◎ ◎ ◎):(:(:◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))

# %%
for d in Odd.distributive(data()): print(d)
# Out:
# (= (:◎ ◎):(:◎) (:◎))
# (= (:◎ ◎ ◎ ◎):(:◎) (:◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎):(:◎) (:◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎):(:◎ ◎ ◎) (:◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎):(:◎ ◎ ◎) (:◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎))
# ...

# %%
for d in Odd.category(data()): print(d)
# Out:
# (= (:◎ ◎):(:(:◎) (:◎)))
# (= (:◎ ◎ ◎ ◎):(:(:◎) (:◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎):(:(:◎) (:◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎):(:(:◎ ◎ ◎) (:◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎) (:◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# (= (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎):(:(:◎ ◎ ◎) (:◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎ ◎)))
# ...

# %%
W.logic()
# Out:
# 'mixed'

# %%
import Space
dims = [(1,1),(2,1),(3,1),(4,1),(5,1),(1,2),(2,2),(3,2),(4,2),(1,3),(1,4),(1,5),(2,3)]
for width,depth in dims:
    print('width:'+str(width),'depth:'+str(depth),Space.Window(width,depth))
# Out:
# width:1 depth:1 eval: False, true: 1, false:1, undecided:0, codas:1, datas:2
# width:2 depth:1 eval: False, true: 1, false:2, undecided:0, codas:1, datas:3
# width:3 depth:1 eval: False, true: 1, false:3, undecided:0, codas:1, datas:4
# width:4 depth:1 eval: False, true: 1, false:4, undecided:0, codas:1, datas:5
# width:5 depth:1 eval: False, true: 1, false:5, undecided:0, codas:1, datas:6
# width:1 depth:2 eval: False, true: 1, false:4, undecided:0, codas:4, datas:5
# width:2 depth:2 eval: False, true: 1, false:90, undecided:0, codas:9, datas:91
# width:3 depth:2 eval: False, true: 1, false:4368, undecided:0, codas:16, datas:4369
# width:4 depth:2 eval: False, true: 1, false:406900, undecided:0, codas:25, datas:406901
# width:1 depth:3 eval: False, true: 1, false:20, undecided:5, codas:25, datas:26
# width:1 depth:4 eval: False, true: 1, false:104, undecided:572, codas:676, datas:677
# width:1 depth:5 eval: False, true: 1, false:2708, undecided:455621, codas:458329, datas:458330
# ...
